# %% [markdown]
# <a href="https://colab.research.google.com/github/anniepeacock/DANSAR/blob/devel/burn_severity/GetData_UAVSAR_TimeSeries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Downloading Available UAVSAR Data (for Time Series & Regeneration) & Making GIS-Ready Products**
#
# *This notebook runs through downloading and pre-processing UAVSAR Data to be used for fire severity analysis over the Verdugo Mountains in Los Angeles*
#
# - Inputs: GRD, INC, and Annotation files
# - Outputs: Masked, cropped, incidence-angle correction, speckle filtered, geotiffs
#
# ----------------
#
# Table of Contents:
# 0. [Running the Notebook](#s1)
# 1. [Download UAVSAR Data](#s2)
# 2. [Generate a HDR File](#s3)
# 3. [Read in data and plot](#s4)
# 4. [Crop and export to geotiff](#s5)

# %% [markdown]
# <a name="s1"></a>
# ## Running the Notebook
# - This Notebook has both "text" and "code" cells. The text cells have text descriptions about running the notebooks and data interpretation.
# - Code cells are a light gray and a "play" button appears in the upper left corner when your mouse is hovered over the cell.
# - To run the content in the code cells, **select the play button** in the upper left corner of each code cell or **press shift-enter**.
#
# ### Python Packages:
# This routine uses the following python libraries. Some are already included in the Google Colab environment and others are installed in the cell below before imported. Downloading new python packages to this environment may take a few minutes to complete.

# %%
# !pip install rasterio --quiet        # Install python package "rasterio" into Google Colab environment
# !pip install earthpy --quiet         # For plot legends
## Using ASF Search
# !pip install asf_search --quiet

# %%
# Scripts and functions needed from GitHub repos
# To build HDR files
# !git clone https://bitbucket.org/nathanmthomas/bucket-of-rs-and-gis-scripts/src/master/BuildUAVSARhdr.py

# To appy Enhanced Lee Speckle Filter
# !git clone https://github.com/NaiaraSPinto/VegMapper.git

# To generate geotiffs and apply incidence angle masking
# !wget https://raw.githubusercontent.com/anniepeacock/DANSAR/devel/utils/functions.py
# Out:
# fatal: destination path 'BuildUAVSARhdr.py' already exists and is not an empty directory.
# fatal: destination path 'VegMapper' already exists and is not an empty directory.
# --2024-05-15 23:42:47--  https://raw.githubusercontent.com/anniepeacock/DANSAR/devel/utils/functions.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5783 (5.6K) [text/plain]
# Saving to: ‘functions.py.1’
#
# functions.py.1      100%[===================>]   5.65K  --.-KB/s    in 0s
#
# 2024-05-15 23:42:47 (42.4 MB/s) - ‘functions.py.1’ saved [5783/5783]

# %%
import rasterio as rio               # Reading and writing raster formats
import numpy as np                   # Numeric and mathematic functions
import matplotlib.pyplot as plt      # Plotting, making graphs
import getpass                       # Discreet way to enter username and password
import os
from osgeo import gdal
from skimage import filters          # For otsu thresholding
import math
import geopandas as gpd
from matplotlib.patches import Patch          # Creates and plots visualization i.e. legends or figures - (Section 3, 4)
from rasterio.plot import plotting_extent     # Creates an object to plot raster and vector data together - (Section 3. HV Change Detection)
import requests
from osgeo import gdal
from rasterio.plot import show_hist
from rasterio.mask import mask as rio_mask
from shapely.geometry import mapping
from rasterio.plot import show
from matplotlib.colors import ListedColormap
import matplotlib.colors as colors
import earthpy.plot as ep
from skimage import filters
from scipy.ndimage.filters import generic_filter
from scipy.stats import mode


# Read in functions from functions.py script
from functions import * #download_files, process_grd_files, process_inc_files, mask_and_save, convert_db

# Read in enhanced lee filter from VegMapper
import sys
path_to_module = '/content/VegMapper/vegmapper/core/'
sys.path.append(path_to_module)
from filter import enhanced_lee
# Out:
# <ipython-input-22-4f7ddbcd74a1>:22: DeprecationWarning: Please use `generic_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import generic_filter

# %% [markdown]
# <a name="s2"></a>
# # 1. Download UAVSAR and NISAR Simulated Data
#
# An Earthdata account is required to download the UAVSAR or NISAR Simulated data stored at ASF to this notebook environment. Create an account here, if needed: https://urs.earthdata.nasa.gov//users/new

# %%
username = getpass.getpass(prompt='Earthdata username:')
password = getpass.getpass(prompt='Earthdata password:')
# Out:
# Earthdata username:··········
# Earthdata password:··········

# %% [markdown]
# Now, download the UAVSAR data and its corresponding annotation file using wget and your Earthdata username and password. The annotation file (.ann) is required to generate a HDR (.hdr) file. This hdr file stores the georeferencing information of an associated raw raster file and is needed to make the UAVSAR GRD files (.grd) GIS-readable.
#
#
# Browse for UAVSAR data of interest here: https://uavsar.jpl.nasa.gov/cgi-bin/data.pl
#
# * To download here, replace the links below with the new data of interest

# %%
import asf_search as asf
session = asf.ASFSession() # Downloading requires session

try:
    user_pass_session = asf.ASFSession().auth_with_creds(username, password)
except asf.ASFAuthenticationError as e:
    print(f'Auth failed: {e}')
else:
    print('Success!')
# Out:
# Auth failed: Username or password is incorrect

# %%
## How do you get HV polarizations from ASF??
help(asf.constants.POLARIZATION)
# Out:
# Help on module asf_search.constants.POLARIZATION in asf_search.constants:
#
# NAME
#     asf_search.constants.POLARIZATION
#
# DATA
#     DUAL_HH = ''
#     DUAL_HV = ''
#     DUAL_VH = ''
#     DUAL_VV = ''
#     FULL = 'full'
#     HH = 'HH'
#     HH_3SCAN = ''
#     HH_4SCAN = ''
#     HH_5SCAN = ''
#     HH_HV = 'HH+HV'
#     HH_HV_VH_VV = 'HH+HV+VH+VV'
#     HH_VV = 'HH+VV'
#     QUAD = 'quadrature'
#     UNKNOWN = 'UNKNOWN'
#     VV = 'VV'
#     VV_VH = 'VV+VH'
#
# FILE
#     /usr/local/lib/python3.10/dist-packages/asf_search/constants/POLARIZATION.py

# %%
# can generate polygon using ASF Vertex AOI tool
wkt = 'POLYGON((-118.3582 34.2487,-118.2604 34.1655,-118.2241 34.1865,-118.3224 34.2681,-118.3582 34.2487))'
results = asf.geo_search(platform=[asf.PLATFORM.UAVSAR], intersectsWith=wkt, processingLevel=asf.PRODUCT_TYPE.AMPLITUDE_GRD, flightLine='08525')
print(results)
# Out:
# {
#   "features": [
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.278706,
#               34.236551
#             ],
#             [
#               -119.262257,
#               34.036094
#             ],
#             [
#               -116.055173,
#               34.239516
#             ],
#             [
#               -116.064811,
#               34.431078
#             ],
#             [
#               -119.278706,
#               34.236551
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_18076-003_20026-016_0708d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_18076-003_20026-016_0708d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1727326957,
#         "centerLat": 34.245539482218,
#         "centerLon": -117.679610845501,
#         "fileID": "UA_SanAnd_08525_18076-003_20026-016_0708d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_18076-003_20026-016_0708d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_18076-003_20026-016_0708d_s01_L090_01",
#         "insarStackId": "-1",
#         "md5sum": "35ceea9555f05986a25b82695001e92e",
#         "orbit": -1,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2020-10-14T06:47:44Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_18076-003_20026-016_0708d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2018-10-11T22:42:15Z",
#         "stopTime": "2020-09-18T20:59:21Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_18076-003_20026-016_0708d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.225209,
#               34.038826
#             ],
#             [
#               -116.808809,
#               34.226866
#             ],
#             [
#               -116.821811,
#               34.395141
#             ],
#             [
#               -119.243762,
#               34.239144
#             ],
#             [
#               -119.225209,
#               34.038826
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_18076-003_18083-003_0036d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_18076-003_18083-003_0036d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1334290900,
#         "centerLat": 34.2284,
#         "centerLon": -118.0613,
#         "fileID": "UA_SanAnd_08525_18076-003_18083-003_0036d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_18076-003_18083-003_0036d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_18076-003_18083-003_0036d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "37cbbaaa1c423a086c60d8f7989d4dd6",
#         "orbit": 18076,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2018-11-20T00:47:34Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_18076-003_18083-003_0036d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2018-10-11T22:42:28Z",
#         "stopTime": "2018-11-16T02:58:46Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_18076-003_18083-003_0036d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.233327,
#               34.03817
#             ],
#             [
#               -116.124851,
#               34.236251
#             ],
#             [
#               -116.13536,
#               34.428195
#             ],
#             [
#               -119.250437,
#               34.238624
#             ],
#             [
#               -119.233327,
#               34.03817
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_17122-003_18076-003_0343d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_17122-003_18076-003_0343d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1679680183,
#         "centerLat": 34.2444548304788,
#         "centerLon": -117.699370490949,
#         "fileID": "UA_SanAnd_08525_17122-003_18076-003_0343d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_17122-003_18076-003_0343d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_17122-003_18076-003_0343d_s01_L090_01",
#         "insarStackId": "-1",
#         "md5sum": "b61528d42bcac8cc1e999b5dc7104e6b",
#         "orbit": -1,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2020-10-14T06:23:33Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_17122-003_18076-003_0343d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2017-11-02T19:38:57Z",
#         "stopTime": "2018-10-11T22:42:26Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_17122-003_18076-003_0343d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.281594,
#               34.23631
#             ],
#             [
#               -119.259079,
#               34.036325
#             ],
#             [
#               -116.052905,
#               34.239889
#             ],
#             [
#               -116.067536,
#               34.430917
#             ],
#             [
#               -119.281594,
#               34.23631
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_14158-003_17122-003_1106d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_14158-003_17122-003_1106d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1729398442,
#         "centerLat": 34.2456,
#         "centerLon": -117.68,
#         "fileID": "UA_SanAnd_08525_14158-003_17122-003_1106d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_14158-003_17122-003_1106d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_14158-003_17122-003_1106d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "3533b7d735687685a10ce475eb3c0437",
#         "orbit": 14158,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2018-04-18T18:53:19Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_14158-003_17122-003_1106d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2014-10-23T20:00:54Z",
#         "stopTime": "2017-11-02T19:38:46Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_14158-003_17122-003_1106d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17047556,
#               34.23579729
#             ],
#             [
#               -116.18734689,
#               34.4251696
#             ],
#             [
#               -119.20295344,
#               34.24210275
#             ],
#             [
#               -119.1778295,
#               34.04219788
#             ],
#             [
#               -116.17047556,
#               34.23579729
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_14006-006_14158-003_0279d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_14006-006_14158-003_0279d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1632263350,
#         "centerLat": 34.2447,
#         "centerLon": -117.7006,
#         "fileID": "UA_SanAnd_08525_14006-006_14158-003_0279d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_14006-006_14158-003_0279d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_14006-006_14158-003_0279d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "14a949671c349a94e787927c9b520e2b",
#         "orbit": 14006,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2015-01-07T00:55:21Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_14006-006_14158-003_0279d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2014-01-17T20:52:25Z",
#         "stopTime": "2014-10-23T20:01:23Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_14006-006_14158-003_0279d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.1596548,
#               34.23609611
#             ],
#             [
#               -116.17651908,
#               34.42571921
#             ],
#             [
#               -119.2414489,
#               34.2392899
#             ],
#             [
#               -119.21625505,
#               34.03941892
#             ],
#             [
#               -116.1596548,
#               34.23609611
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_14006-006_14158-003_0279d_s01_L090HH_02.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_14006-006_14158-003_0279d_s01_L090HH_02.cor.png"
#         ],
#         "bytes": 1654219694,
#         "centerLat": 34.2438,
#         "centerLon": -117.7143,
#         "fileID": "UA_SanAnd_08525_14006-006_14158-003_0279d_s01_L090_02-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_14006-006_14158-003_0279d_s01_L090_02_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_14006-006_14158-003_0279d_s01_L090_02",
#         "insarStackId": "0",
#         "md5sum": "8a5642e41748ac371d35c533a62bc877",
#         "orbit": 14006,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2016-05-04T19:22:05Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_14006-006_14158-003_0279d_s01_L090_02",
#         "sensor": "UAVSAR",
#         "startTime": "2014-01-17T20:52:11Z",
#         "stopTime": "2014-10-23T20:01:09Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_14006-006_14158-003_0279d_s01_L090_02_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.281473,
#               34.236333
#             ],
#             [
#               -119.254067,
#               34.036665
#             ],
#             [
#               -116.098997,
#               34.236621
#             ],
#             [
#               -116.118546,
#               34.42887
#             ],
#             [
#               -119.281473,
#               34.236333
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_14158-003_1861d_s01_L090HH_02.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_14158-003_1861d_s01_L090HH_02.cor.png"
#         ],
#         "bytes": 1702611583,
#         "centerLat": 34.2441,
#         "centerLon": -117.7008,
#         "fileID": "UA_SanAnd_08525_09072-002_14158-003_1861d_s01_L090_02-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_09072-002_14158-003_1861d_s01_L090_02_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_09072-002_14158-003_1861d_s01_L090_02",
#         "insarStackId": "0",
#         "md5sum": "d48b444e4443194bbd179d6d862f85db",
#         "orbit": 9072,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2017-07-18T14:45:47Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_09072-002_14158-003_1861d_s01_L090_02",
#         "sensor": "UAVSAR",
#         "startTime": "2009-09-18T14:36:25Z",
#         "stopTime": "2014-10-23T20:00:55Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_09072-002_14158-003_1861d_s01_L090_02_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.25417707,
#               34.03665141
#             ],
#             [
#               -116.0991079,
#               34.2366145
#             ],
#             [
#               -116.11865859,
#               34.42886522
#             ],
#             [
#               -119.28158476,
#               34.23632303
#             ],
#             [
#               -119.25417707,
#               34.03665141
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_14158-003_1861d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_14158-003_1861d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1702523523,
#         "centerLat": 34.2441,
#         "centerLon": -117.7009,
#         "fileID": "UA_SanAnd_08525_09072-002_14158-003_1861d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_09072-002_14158-003_1861d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_09072-002_14158-003_1861d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "e64e947c39319ce5c3fb7c3aaafabdea",
#         "orbit": 9072,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2016-05-04T23:50:46Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_09072-002_14158-003_1861d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2009-09-18T14:36:25Z",
#         "stopTime": "2014-10-23T20:00:54Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_09072-002_14158-003_1861d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.14656851,
#               34.23598013
#             ],
#             [
#               -116.17070142,
#               34.42614401
#             ],
#             [
#               -119.23528467,
#               34.23973209
#             ],
#             [
#               -119.2013403,
#               34.04025493
#             ],
#             [
#               -116.14656851,
#               34.23598013
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_13096-002_14006-006_0234d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_13096-002_14006-006_0234d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1654901117,
#         "centerLat": 34.2443,
#         "centerLon": -117.7034,
#         "fileID": "UA_SanAnd_08525_13096-002_14006-006_0234d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_13096-002_14006-006_0234d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_13096-002_14006-006_0234d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "295148a77025e8d7b23592aedf3a6d05",
#         "orbit": 13096,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-03-11T01:28:25Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_13096-002_14006-006_0234d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2013-05-28T15:44:13Z",
#         "stopTime": "2014-01-17T20:52:14Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_13096-002_14006-006_0234d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.16169702,
#               34.23605871
#             ],
#             [
#               -116.1796392,
#               34.42554183
#             ],
#             [
#               -119.24409964,
#               34.2390907
#             ],
#             [
#               -119.21748312,
#               34.03930836
#             ],
#             [
#               -116.16169702,
#               34.23605871
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12135-006_14006-006_0424d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12135-006_14006-006_0424d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1654622193,
#         "centerLat": 34.2437,
#         "centerLon": -117.7167,
#         "fileID": "UA_SanAnd_08525_12135-006_14006-006_0424d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_12135-006_14006-006_0424d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_12135-006_14006-006_0424d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "793a16adeebf0a2784898181217a3e96",
#         "orbit": 12135,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T15:46:21Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_12135-006_14006-006_0424d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2012-11-19T22:34:34Z",
#         "stopTime": "2014-01-17T20:52:10Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_12135-006_14006-006_0424d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.16325891,
#               34.23603418
#             ],
#             [
#               -116.17990219,
#               34.42553347
#             ],
#             [
#               -119.24470837,
#               34.23905733
#             ],
#             [
#               -119.21964623,
#               34.03919289
#             ],
#             [
#               -116.16325891,
#               34.23603418
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12021-006_14006-006_0630d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12021-006_14006-006_0630d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1654720175,
#         "centerLat": 34.2436,
#         "centerLon": -117.7179,
#         "fileID": "UA_SanAnd_08525_12021-006_14006-006_0630d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_12021-006_14006-006_0630d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_12021-006_14006-006_0630d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "1a793b010136ac309591f78cd2873440",
#         "orbit": 12021,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-03-11T22:55:15Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_12021-006_14006-006_0630d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2012-04-27T19:04:22Z",
#         "stopTime": "2014-01-17T20:52:09Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_12021-006_14006-006_0630d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.16658512,
#               34.2360093
#             ],
#             [
#               -116.17885632,
#               34.42560346
#             ],
#             [
#               -119.24616947,
#               34.23895047
#             ],
#             [
#               -119.22691915,
#               34.03868866
#             ],
#             [
#               -116.16658512,
#               34.2360093
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12134-001_14006-006_0428d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12134-001_14006-006_0428d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1656175008,
#         "centerLat": 34.2435,
#         "centerLon": -117.7208,
#         "fileID": "UA_SanAnd_08525_12134-001_14006-006_0428d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_12134-001_14006-006_0428d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_12134-001_14006-006_0428d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "4b75229e204a9c5ec91484b2af13f4a7",
#         "orbit": 12134,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T15:16:27Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_12134-001_14006-006_0428d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2012-11-15T15:50:38Z",
#         "stopTime": "2014-01-17T20:52:08Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_12134-001_14006-006_0428d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.25470386,
#               34.0366317
#             ],
#             [
#               -116.09959987,
#               34.2365997
#             ],
#             [
#               -116.1181855,
#               34.42887051
#             ],
#             [
#               -119.28110808,
#               34.23636405
#             ],
#             [
#               -119.25470386,
#               34.0366317
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_14006-006_1582d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_14006-006_1582d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1702116182,
#         "centerLat": 34.2441,
#         "centerLon": -117.701,
#         "fileID": "UA_SanAnd_08525_09072-002_14006-006_1582d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_09072-002_14006-006_1582d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_09072-002_14006-006_1582d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "adc493a01c5545efde71e0c3276a367d",
#         "orbit": 9072,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-03-17T05:32:44Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_09072-002_14006-006_1582d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2009-09-18T14:36:26Z",
#         "stopTime": "2014-01-17T20:51:56Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_09072-002_14006-006_1582d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.227408,
#               34.038669
#             ],
#             [
#               -116.168138,
#               34.235949
#             ],
#             [
#               -116.182297,
#               34.425422
#             ],
#             [
#               -119.24908,
#               34.238729
#             ],
#             [
#               -119.227408,
#               34.038669
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090HH_03.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090HH_03.cor.png"
#         ],
#         "bytes": 1653500358,
#         "centerLat": 34.2434,
#         "centerLon": -117.7229,
#         "fileID": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_03-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_12134-001_12135-006_0004d_s01_L090_03_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_03",
#         "insarStackId": "0",
#         "md5sum": "84cd9ab60fdfe537c6db2adc456df57d",
#         "orbit": 12134,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2017-03-21T19:25:22Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_03",
#         "sensor": "UAVSAR",
#         "startTime": "2012-11-15T15:50:38Z",
#         "stopTime": "2012-11-19T22:34:31Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090_03_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -119.227408,
#               34.038669
#             ],
#             [
#               -116.168138,
#               34.235949
#             ],
#             [
#               -116.182297,
#               34.425422
#             ],
#             [
#               -119.24908,
#               34.238729
#             ],
#             [
#               -119.227408,
#               34.038669
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090HH_02.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090HH_02.cor.png"
#         ],
#         "bytes": 1653500462,
#         "centerLat": 34.2434,
#         "centerLon": -117.7229,
#         "fileID": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_02-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_12134-001_12135-006_0004d_s01_L090_02_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_02",
#         "insarStackId": "0",
#         "md5sum": "9037a3d17a13676312866dd1fe25aac6",
#         "orbit": 12134,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2016-11-09T03:03:41Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_02",
#         "sensor": "UAVSAR",
#         "startTime": "2012-11-15T15:50:38Z",
#         "stopTime": "2012-11-19T22:34:31Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090_02_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.16781494,
#               34.23591343
#             ],
#             [
#               -116.18634544,
#               34.42521214
#             ],
#             [
#               -119.25138287,
#               34.238548
#             ],
#             [
#               -119.22387789,
#               34.03883339
#             ],
#             [
#               -116.16781494,
#               34.23591343
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12021-006_12135-006_0206d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12021-006_12135-006_0206d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1654582684,
#         "centerLat": 34.2433,
#         "centerLon": -117.7235,
#         "fileID": "UA_SanAnd_08525_12021-006_12135-006_0206d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_12021-006_12135-006_0206d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_12021-006_12135-006_0206d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "f43f4b093a92bc658dad1239f09b8a96",
#         "orbit": 12021,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T07:05:56Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_12021-006_12135-006_0206d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2012-04-27T19:04:20Z",
#         "stopTime": "2012-11-19T22:34:31Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_12021-006_12135-006_0206d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.16838465,
#               34.23591765
#             ],
#             [
#               -116.18569249,
#               34.42525095
#             ],
#             [
#               -119.2505425,
#               34.23862035
#             ],
#             [
#               -119.22479688,
#               34.03882828
#             ],
#             [
#               -116.16838465,
#               34.23591765
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_11068-002_12135-006_0388d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_11068-002_12135-006_0388d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1653577500,
#         "centerLat": 34.2433,
#         "centerLon": -117.7235,
#         "fileID": "UA_SanAnd_08525_11068-002_12135-006_0388d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_11068-002_12135-006_0388d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_11068-002_12135-006_0388d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "3132ad74841a63d04847d953ae67ac9f",
#         "orbit": 11068,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T19:23:00Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_11068-002_12135-006_0388d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2011-10-28T03:04:58Z",
#         "stopTime": "2012-11-19T22:34:31Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_11068-002_12135-006_0388d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.1712031,
#               34.23579507
#             ],
#             [
#               -116.18536806,
#               34.42527373
#             ],
#             [
#               -119.25221385,
#               34.23849468
#             ],
#             [
#               -119.23053721,
#               34.03843658
#             ],
#             [
#               -116.1712031,
#               34.23579507
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1655143670,
#         "centerLat": 34.2432,
#         "centerLon": -117.726,
#         "fileID": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_12134-001_12135-006_0004d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "275a125e9145766e5a8d24f75f326df7",
#         "orbit": 12134,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T22:35:13Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_12134-001_12135-006_0004d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2012-11-15T15:50:37Z",
#         "stopTime": "2012-11-19T22:34:30Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_12134-001_12135-006_0004d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17210011,
#               34.23573507
#             ],
#             [
#               -116.18496796,
#               34.42528479
#             ],
#             [
#               -119.25107234,
#               34.23857885
#             ],
#             [
#               -119.23094337,
#               34.03839332
#             ],
#             [
#               -116.17210011,
#               34.23573507
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12021-006_12134-001_0202d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_12021-006_12134-001_0202d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1655530067,
#         "centerLat": 34.2432,
#         "centerLon": -117.7259,
#         "fileID": "UA_SanAnd_08525_12021-006_12134-001_0202d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_12021-006_12134-001_0202d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_12021-006_12134-001_0202d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "bd15c99371adf76744501f5feea1a330",
#         "orbit": 12021,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T21:28:12Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_12021-006_12134-001_0202d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2012-04-27T19:04:19Z",
#         "stopTime": "2012-11-15T15:50:37Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_12021-006_12134-001_0202d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17140601,
#               34.2357568
#             ],
#             [
#               -116.18299162,
#               34.42537255
#             ],
#             [
#               -119.24953816,
#               34.23869182
#             ],
#             [
#               -119.23124958,
#               34.03834573
#             ],
#             [
#               -116.17140601,
#               34.2357568
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_11047-003_12134-001_0496d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_11047-003_12134-001_0496d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1655746489,
#         "centerLat": 34.2432,
#         "centerLon": -117.725,
#         "fileID": "UA_SanAnd_08525_11047-003_12134-001_0496d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_11047-003_12134-001_0496d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_11047-003_12134-001_0496d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "ba1ae40dd7a306964fff988c5d5423f2",
#         "orbit": 11047,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T20:21:33Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_11047-003_12134-001_0496d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2011-07-08T17:28:29Z",
#         "stopTime": "2012-11-15T15:50:37Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_11047-003_12134-001_0496d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17336883,
#               34.2356764
#             ],
#             [
#               -116.18501186,
#               34.42528957
#             ],
#             [
#               -119.2527155,
#               34.23846532
#             ],
#             [
#               -119.23433271,
#               34.03814736
#             ],
#             [
#               -116.17336883,
#               34.2356764
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_11068-002_12134-001_0384d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_11068-002_12134-001_0384d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1654468461,
#         "centerLat": 34.2431,
#         "centerLon": -117.7275,
#         "fileID": "UA_SanAnd_08525_11068-002_12134-001_0384d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_11068-002_12134-001_0384d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_11068-002_12134-001_0384d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "9f9c151170c7aeacbd64d89ffa3ab59e",
#         "orbit": 11068,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T08:28:06Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_11068-002_12134-001_0384d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2011-10-28T03:04:57Z",
#         "stopTime": "2012-11-15T15:50:36Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_11068-002_12134-001_0384d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.16344997,
#               34.23604409
#             ],
#             [
#               -116.17940443,
#               34.42556447
#             ],
#             [
#               -119.24509718,
#               34.23903354
#             ],
#             [
#               -119.22100142,
#               34.0391143
#             ],
#             [
#               -116.16344997,
#               34.23604409
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_11047-003_12021-006_0294d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_11047-003_12021-006_0294d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1654429143,
#         "centerLat": 34.2436,
#         "centerLon": -117.7182,
#         "fileID": "UA_SanAnd_08525_11047-003_12021-006_0294d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_11047-003_12021-006_0294d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_11047-003_12021-006_0294d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "2e6579b8738f37fb4f81d8d4572d89c6",
#         "orbit": 11047,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T22:02:25Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_11047-003_12021-006_0294d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2011-07-08T17:28:32Z",
#         "stopTime": "2012-04-27T19:04:22Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_11047-003_12021-006_0294d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17369892,
#               34.23564596
#             ],
#             [
#               -116.18694981,
#               34.42519567
#             ],
#             [
#               -119.2029556,
#               34.24212122
#             ],
#             [
#               -119.18247996,
#               34.04190132
#             ],
#             [
#               -116.17369892,
#               34.23564596
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10085-005_11068-002_0325d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10085-005_11068-002_0325d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1633362782,
#         "centerLat": 34.2446,
#         "centerLon": -117.7024,
#         "fileID": "UA_SanAnd_08525_10085-005_11068-002_0325d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_10085-005_11068-002_0325d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_10085-005_11068-002_0325d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "8c10e4f0fb49887069654582f82ce738",
#         "orbit": 10085,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-12-10T01:21:10Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_10085-005_11068-002_0325d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2010-12-07T01:09:24Z",
#         "stopTime": "2011-10-28T03:05:16Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_10085-005_11068-002_0325d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.16977265,
#               34.23586414
#             ],
#             [
#               -116.18440648,
#               34.42531191
#             ],
#             [
#               -119.24921976,
#               34.23873247
#             ],
#             [
#               -119.2268605,
#               34.03872243
#             ],
#             [
#               -116.16977265,
#               34.23586414
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10072-005_11068-002_0379d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10072-005_11068-002_0379d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1654525414,
#         "centerLat": 34.2433,
#         "centerLon": -117.7237,
#         "fileID": "UA_SanAnd_08525_10072-005_11068-002_0379d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_10072-005_11068-002_0379d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_10072-005_11068-002_0379d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "6d18980684d8a45aae1f73a74d250a95",
#         "orbit": 10072,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T06:33:34Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_10072-005_11068-002_0379d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2010-10-14T01:22:06Z",
#         "stopTime": "2011-10-28T03:04:59Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_10072-005_11068-002_0379d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17052641,
#               34.23576954
#             ],
#             [
#               -116.18676836,
#               34.42517786
#             ],
#             [
#               -119.2025304,
#               34.2421343
#             ],
#             [
#               -119.1784274,
#               34.0421494
#             ],
#             [
#               -116.17052641,
#               34.23576954
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10029-005_11047-003_0449d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10029-005_11047-003_0449d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1632377093,
#         "centerLat": 34.2447,
#         "centerLon": -117.7005,
#         "fileID": "UA_SanAnd_08525_10029-005_11047-003_0449d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_10029-005_11047-003_0449d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
# ...
#         "sensor": "UAVSAR",
#         "startTime": "2009-09-18T14:36:58Z",
#         "stopTime": "2010-12-07T01:09:25Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_09072-002_10085-005_0445d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17418405,
#               34.23558328
#             ],
#             [
#               -116.18894183,
#               34.42508834
#             ],
#             [
#               -119.2053642,
#               34.24192614
#             ],
#             [
#               -119.18304093,
#               34.04181605
#             ],
#             [
#               -116.17418405,
#               34.23558328
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10029-005_10085-005_0236d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10029-005_10085-005_0236d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1633760823,
#         "centerLat": 34.2445,
#         "centerLon": -117.7038,
#         "fileID": "UA_SanAnd_08525_10029-005_10085-005_0236d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_10029-005_10085-005_0236d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_10029-005_10085-005_0236d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "e165acce2c5cd23975f0c11478ae5a17",
#         "orbit": 10029,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-12-02T21:59:47Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_10029-005_10085-005_0236d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2010-04-15T19:28:59Z",
#         "stopTime": "2010-12-07T01:09:24Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_10029-005_10085-005_0236d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17667022,
#               34.23554225
#             ],
#             [
#               -116.18884538,
#               34.42509893
#             ],
#             [
#               -119.20480538,
#               34.24196825
#             ],
#             [
#               -119.1858502,
#               34.04159671
#             ],
#             [
#               -116.17667022,
#               34.23554225
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10025-001_10085-005_0279d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10025-001_10085-005_0279d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1633946877,
#         "centerLat": 34.2444,
#         "centerLon": -117.705,
#         "fileID": "UA_SanAnd_08525_10025-001_10085-005_0279d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_10025-001_10085-005_0279d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_10025-001_10085-005_0279d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "e251d0aec8801f4e1ceeb89baca51906",
#         "orbit": 10025,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-12-10T08:56:45Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_10025-001_10085-005_0279d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2010-03-03T20:29:38Z",
#         "stopTime": "2010-12-07T01:09:23Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_10025-001_10085-005_0279d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.13776135,
#               34.23617932
#             ],
#             [
#               -116.15089622,
#               34.42758332
#             ],
#             [
#               -119.21559852,
#               34.24121191
#             ],
#             [
#               -119.1951965,
#               34.04100047
#             ],
#             [
#               -116.13776135,
#               34.23617932
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10072-005_10085-005_0054d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10072-005_10085-005_0054d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1658001513,
#         "centerLat": 34.2453,
#         "centerLon": -117.6885,
#         "fileID": "UA_SanAnd_08525_10072-005_10085-005_0054d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_10072-005_10085-005_0054d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_10072-005_10085-005_0054d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "aabad038e41d0c2dc4de99cf47403967",
#         "orbit": 10072,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2015-04-19T02:11:25Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_10072-005_10085-005_0054d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2010-10-14T01:22:19Z",
#         "stopTime": "2010-12-07T01:09:20Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_10072-005_10085-005_0054d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17499435,
#               34.23555738
#             ],
#             [
#               -116.19114715,
#               34.42498909
#             ],
#             [
#               -119.20699581,
#               34.2418088
#             ],
#             [
#               -119.18287693,
#               34.04182653
#             ],
#             [
#               -116.17499435,
#               34.23555738
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10029-005_10072-005_0182d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10029-005_10072-005_0182d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1633384958,
#         "centerLat": 34.2444,
#         "centerLon": -117.7049,
#         "fileID": "UA_SanAnd_08525_10029-005_10072-005_0182d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_10029-005_10072-005_0182d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_10029-005_10072-005_0182d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "132767ad4de019d606573d3deabe0fe4",
#         "orbit": 10029,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-12-10T00:27:58Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_10029-005_10072-005_0182d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2010-04-15T19:28:59Z",
#         "stopTime": "2010-10-14T01:22:23Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_10029-005_10072-005_0182d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.17809497,
#               34.23553139
#             ],
#             [
#               -116.19167365,
#               34.42497519
#             ],
#             [
#               -119.20705726,
#               34.24180732
#             ],
#             [
#               -119.18630494,
#               34.04158993
#             ],
#             [
#               -116.17809497,
#               34.23553139
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10025-001_10072-005_0225d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_10025-001_10072-005_0225d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1633535189,
#         "centerLat": 34.2443,
#         "centerLon": -117.7068,
#         "fileID": "UA_SanAnd_08525_10025-001_10072-005_0225d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_10025-001_10072-005_0225d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_10025-001_10072-005_0225d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "d568dacfa8090574c6b7b1505bc70400",
#         "orbit": 10025,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-12-10T03:21:01Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_10025-001_10072-005_0225d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2010-03-03T20:29:37Z",
#         "stopTime": "2010-10-14T01:22:22Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_10025-001_10072-005_0225d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.14158612,
#               34.2360504
#             ],
#             [
#               -116.15870696,
#               34.42710414
#             ],
#             [
#               -119.02628976,
#               34.25493801
#             ],
#             [
#               -119.00164418,
#               34.05479705
#             ],
#             [
#               -116.14158612,
#               34.2360504
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_10072-005_0391d_s01_L090HH_01.hgt.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_10072-005_0391d_s01_L090HH_01.cor.png"
#         ],
#         "bytes": 1558888353,
#         "centerLat": 34.2509,
#         "centerLon": -117.5952,
#         "fileID": "UA_SanAnd_08525_09072-002_10072-005_0391d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_09072-002_10072-005_0391d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_09072-002_10072-005_0391d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "24bf1ad66c0568d94cc65ff777129041",
#         "orbit": 9072,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2012-05-17T00:00:59Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_09072-002_10072-005_0391d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2009-09-18T14:36:11Z",
#         "stopTime": "2010-10-14T01:21:40Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_09072-002_10072-005_0391d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.16803222,
#               34.23589381
#             ],
#             [
#               -116.18672763,
#               34.42518216
#             ],
#             [
#               -119.20255145,
#               34.24214463
#             ],
#             [
#               -119.17533644,
#               34.042362
#             ],
#             [
#               -116.16803222,
#               34.23589381
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_10029-005_0209d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_10029-005_0209d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1633451722,
#         "centerLat": 34.2448,
#         "centerLon": -117.6991,
#         "fileID": "UA_SanAnd_08525_09072-002_10029-005_0209d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_09072-002_10029-005_0209d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_09072-002_10029-005_0209d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "0bcb63179cdd1155ba5325fefdb2317e",
#         "orbit": 9072,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-12-02T23:45:01Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_09072-002_10029-005_0209d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2009-09-18T14:36:58Z",
#         "stopTime": "2010-04-15T19:29:01Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_09072-002_10029-005_0209d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     },
#     {
#       "geometry": {
#         "coordinates": [
#           [
#             [
#               -116.1593298,
#               34.23611101
#             ],
#             [
#               -116.17545247,
#               34.42577567
#             ],
#             [
#               -119.24005744,
#               34.23941038
#             ],
#             [
#               -119.21613861,
#               34.03946095
#             ],
#             [
#               -116.1593298,
#               34.23611101
#             ]
#           ]
#         ],
#         "type": "Polygon"
#       },
#       "properties": {
#         "beamModeType": "RPI",
#         "browse": [
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_10025-001_0166d_s01_L090HH_01.cor.png",
#           "https://datapool.asf.alaska.edu/BROWSE/UA/SanAnd_08525_09072-002_10025-001_0166d_s01_L090HH_01.hgt.png"
#         ],
#         "bytes": 1657389274,
#         "centerLat": 34.2439,
#         "centerLon": -117.7135,
#         "fileID": "UA_SanAnd_08525_09072-002_10025-001_0166d_s01_L090_01-AMPLITUDE_GRD",
#         "fileName": "SanAnd_08525_09072-002_10025-001_0166d_s01_L090_01_amp_grd.zip",
#         "flightDirection": null,
#         "frameNumber": 685,
#         "granuleType": "UAVSAR_INSAR_SCENE",
#         "groupID": "UA_SanAnd_08525_09072-002_10025-001_0166d_s01_L090_01",
#         "insarStackId": "0",
#         "md5sum": "94f106346b22f7911565c0c93b3e7003",
#         "orbit": 9072,
#         "pathNumber": 8525,
#         "platform": "UAVSAR",
#         "polarization": "HH",
#         "processingDate": "2014-04-29T09:26:41Z",
#         "processingLevel": "AMPLITUDE_GRD",
#         "sceneName": "UA_SanAnd_08525_09072-002_10025-001_0166d_s01_L090_01",
#         "sensor": "UAVSAR",
#         "startTime": "2009-09-18T14:36:42Z",
#         "stopTime": "2010-03-03T20:29:26Z",
#         "url": "https://datapool.asf.alaska.edu/AMPLITUDE_GRD/UA/SanAnd_08525_09072-002_10025-001_0166d_s01_L090_01_amp_grd.zip"
#       },
#       "type": "Feature"
#     }
#   ],
#   "type": "FeatureCollection"
# }

# %%
urls = ['https://uavsar.asf.alaska.edu/UA_SanAnd_08525_23008_011_230712_L090_CX_01/SanAnd_08525_23008_011_230712_L090HVHV_CX_01.grd']
asf.download_urls(urls=urls,  path = './', session=session)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py in _try_get_response(session, url)
#     110     try:
# --> 111         response.raise_for_status()
#     112     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://urs.earthdata.nasa.gov/oauth/authorize?response_type=code&client_id=BO_n7nTIlMljdvU6kRRB3g&redirect_uri=https://auth.asf.alaska.edu/login&state=https://uavsar.asf.alaska.edu/UA_SanAnd_08525_23008_011_230712_L090_CX_01/SanAnd_08525_23008_011_230712_L090HVHV_CX_01.grd&app_type=401
#
# During handling of the above exception, another exception occurred:
#
# ASFAuthenticationError                    Traceback (most recent call last)
# <ipython-input-36-240bb49aac84> in <cell line: 2>()
#       1 urls = ['https://uavsar.asf.alaska.edu/UA_SanAnd_08525_23008_011_230712_L090_CX_01/SanAnd_08525_23008_011_230712_L090HVHV_CX_01.grd']
# ----> 2 asf.download_urls(urls=urls,  path = './', session=session)
#
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py in download_urls(urls, path, session, processes)
#      39     if processes <= 1:
#      40         for url in urls:
# ---> 41             download_url(url=url, path=path, session=session)
#      42     else:
#      43         pool = Pool(processes=processes)
#
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py in download_url(url, path, filename, session)
#      72         session = ASFSession()
#      73
# ---> 74     response = _try_get_response(session=session, url=url)
#      75
#      76     with open(os.path.join(path, filename), 'wb') as f:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     287         @functools.wraps(f)
#     288         def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289             return self(f, *args, **kw)
#     290
#     291         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     377         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378         while True:
# --> 379             do = self.iter(retry_state=retry_state)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     312         is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313         if not (is_explicit_retry or self.retry(retry_state)):
# --> 314             return fut.result()
#     315
#     316         if self.after is not None:
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.10/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     380             if isinstance(do, DoAttempt):
#     381                 try:
# --> 382                     result = fn(*args, **kwargs)
#     383                 except BaseException:  # noqa: B902
#     384                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py in _try_get_response(session, url)
#     112     except HTTPError as e:
#     113         if 400 <= response.status_code <= 499:
# --> 114             raise ASFAuthenticationError(f'HTTP {e.response.status_code}: {e.response.text}')
#     115
#     116         raise e
#
# ASFAuthenticationError: HTTP 401: HTTP Basic: Access denied.

# %%
granule_list = [
    'UA_SanAnd_08525_14158_003_141023_L090HVHV_CX_01-PROJECTED',
    'UA_SanAnd_26526_14092_007_140624_L090HVHV_CX_01-PROJECTED',
    'UA_SanAnd_08525_17122_003_171102_L090HVHV_CX_01-PROJECTED',
    'UA_SanAnd_26526_17122_004_171102_L090HVHV_CX_01-PROJECTED',
    'UA_SanAnd_26526_17122_004_171102_L090_CX_01-INC',
    'UA_SanAnd_08525_17122_003_171102_L090_CX_01-INC',
    'UA_SanAnd_26526_14092_007_140624_L090_CX_01-METADATA',
    'UA_SanAnd_08525_14158_003_141023_L090_CX_01-METADATA',
    'UA_SanAnd_26526_17122_004_171102_L090_CX_01-METADATA',
    'UA_SanAnd_08525_17122_003_171102_L090_CX_01-METADATA',
]
results = asf.granule_search(granule_list=granule_list)

print(f'{len(results)} results found')
# Out:
# 6 results found

# %%
results.download(path='./', session=user_pass_session, processes=10)
# Out:
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: ./SanAnd_26526_17122_004_171102_L090_CX_01.inc
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: ./SanAnd_08525_17122_003_171102_L090_CX_01.ann
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: ./SanAnd_26526_14092_007_140624_L090_CX_01.ann
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: ./SanAnd_26526_17122_004_171102_L090_CX_01.ann
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: ./SanAnd_08525_17122_003_171102_L090_CX_01.inc
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')
# /usr/local/lib/python3.10/dist-packages/asf_search/download/download.py:68: UserWarning: File already exists, skipping download: ./SanAnd_08525_14158_003_141023_L090_CX_01.ann
#   warnings.warn(f'File already exists, skipping download: {os.path.join(path, filename)}')

# %% [markdown]
# <a name="s3"></a>
# # 2. Generate a HDR file
#
# Generate HDR files for each of the GRDs, so they can be GIS-compatible and converted to geotiffs.

# %%
# !python3 "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py" -h
# Out:
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# usage: BuildUAVSARhdr.py [-h] [-i INPUT] [-r UAVSAR] [-p POLARIZATION]
#
# options:
#   -h, --help            show this help message and exit
#   -i INPUT, --input INPUT
#                         Specify the input UAVSAR ann file
#   -r UAVSAR, --uavsar UAVSAR
#                         Specify the input UAVSAR radar file
#   -p POLARIZATION, --polarization POLARIZATION
#                         Specify the input UAVSAR polarization in UPPERCASE (i.e HHHV, HHHH, VVVV,
#                         AMP1, AMP2, COR, UNW, HGT, INT)

# %%
def run_hdr_script(directory, polarization):
    file_data = []

    # Find GRD and annotation files
    for filename in os.listdir(directory):
        if filename.endswith('.grd'):
            grd_file = filename
            annotation_file = filename.replace(f'_L090{polarization}_', '_L090_').replace('.grd', '.ann')
            file_data.append((grd_file, annotation_file))
        elif filename.endswith('.inc'):
            grd_file = filename
            annotation_file = filename.replace(f'_L090{polarization}_', '_L090_').replace('.inc', '.ann')
            file_data.append((grd_file, annotation_file))

    # Run HDR script for each file
    for grd_file, annotation_file in file_data:
        # !python3 "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py" -i {annotation_file} -r {grd_file} -p {polarization}

# Run HDR script for HVHV polarization
run_hdr_script('./', 'HVHV')

# Run HDR script for HHHH polarization
run_hdr_script('./', 'HHHH')

# Run HDR script for incidence angle files (assuming .inc files)
run_hdr_script('./', 'HVHV')  # You can put whichever polarization, using HVHV as a placeholder here
# Out:
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.4433
# UPPER LEFT LONG =  -119.2884
# SAMPLES = 4136
# Lines = 32329
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_08525_14158_003_141023_L090HVHV_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_08525_14158_003_141023_L090HVHV_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.443200000000004
# UPPER LEFT LONG =  -119.2896
# SAMPLES = 4135
# Lines = 32317
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_08525_17122_003_171102_L090HVHV_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_08525_17122_003_171102_L090HVHV_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_26526_14092_007_140624_L090HHHH_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_26526_17122_004_171102_L090HHHH_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.5572
# UPPER LEFT LONG =  -119.3376
# SAMPLES = 5128
# Lines = 32857
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_26526_17122_004_171102_L090HVHV_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_26526_17122_004_171102_L090HVHV_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_08525_14158_003_141023_L090HHHH_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_08525_17122_003_171102_L090HHHH_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.557
# UPPER LEFT LONG =  -119.3376
# SAMPLES = 5126
# Lines = 32833
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_26526_14092_007_140624_L090HVHV_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_26526_14092_007_140624_L090HVHV_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_08525_14158_003_141023_L090HVHV_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_08525_17122_003_171102_L090HVHV_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.557
# UPPER LEFT LONG =  -119.3376
# SAMPLES = 5126
# Lines = 32833
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_26526_14092_007_140624_L090HHHH_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_26526_14092_007_140624_L090HHHH_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.5572
# UPPER LEFT LONG =  -119.3376
# SAMPLES = 5128
# Lines = 32857
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_26526_17122_004_171102_L090HHHH_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_26526_17122_004_171102_L090HHHH_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_26526_17122_004_171102_L090HVHV_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.4433
# UPPER LEFT LONG =  -119.2884
# SAMPLES = 4136
# Lines = 32329
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_08525_14158_003_141023_L090HHHH_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_08525_14158_003_141023_L090HHHH_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.443200000000004
# UPPER LEFT LONG =  -119.2896
# SAMPLES = 4135
# Lines = 32317
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_08525_17122_003_171102_L090HHHH_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_08525_17122_003_171102_L090HHHH_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_26526_14092_007_140624_L090HVHV_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.4433
# UPPER LEFT LONG =  -119.2884
# SAMPLES = 4136
# Lines = 32329
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_08525_14158_003_141023_L090HVHV_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_08525_14158_003_141023_L090HVHV_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.443200000000004
# UPPER LEFT LONG =  -119.2896
# SAMPLES = 4135
# Lines = 32317
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_08525_17122_003_171102_L090HVHV_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_08525_17122_003_171102_L090HVHV_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_26526_14092_007_140624_L090HHHH_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_26526_17122_004_171102_L090HHHH_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.5572
# UPPER LEFT LONG =  -119.3376
# SAMPLES = 5128
# Lines = 32857
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_26526_17122_004_171102_L090HVHV_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_26526_17122_004_171102_L090HVHV_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py
#
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_08525_14158_003_141023_L090HHHH_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# Traceback (most recent call last):
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 127, in <module>
#     main()
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 123, in main
#     genHDRfromTXT(args)
#   File "/content/BuildUAVSARhdr.py/BuildUAVSARhdr.py", line 31, in genHDRfromTXT
#     annFile = open(file, 'r')
# FileNotFoundError: [Errno 2] No such file or directory: 'SanAnd_08525_17122_003_171102_L090HHHH_CG_138A_02.ann'
# UAVSAR.py is written by Nathan Thomas (nmthomas28@gmail.com, @DrNASApants)  formerly of the Aberystwyth University Earth Observation and Ecosystems Dynamics Laboratory (@AU_EarthObs) as part of a visiting research program at NASA JPL. Ammended to process UAVSAR InSAR pair data by Yang Zheng (April 2015).
# Use '-h' for help and required input parameters
#
# UPPER LEFT LAT =  34.557
# UPPER LEFT LONG =  -119.3376
# SAMPLES = 5126
# Lines = 32833
# PIXEL SIZE =  0.0001
# DATATYPE =  4
# SanAnd_26526_14092_007_140624_L090HVHV_CG_138A_02.grd.hdr
# Writing output HDR file...
# Output HDR file = SanAnd_26526_14092_007_140624_L090HVHV_CG_138A_02.grd.hdr
#
# Thank you for using UAVSAR.py

# %% [markdown]
# <a name="s5"></a>
# # 4. Crop the data and export subset to geotiff

# %%
# Define input directory and output directory
input_directory = './' # Directory containing GRD and INC files
output_directory = './'  # Directory to save processed files

# Define extent and projection details
upper_left_x = 373624.5024220281047747
upper_left_y = 3780585.1359808142296970
lower_right_x = 387664.5024220281047747
lower_right_y = 3791835.1359808142296970
window = (upper_left_x, upper_left_y, lower_right_x, lower_right_y)

projection = 'EPSG:26911' # reprojecting here to be in meters to match the Landsat data that will be reprojected in meters.

# %%
# Process GRD files
process_grd_files(input_directory, output_directory, window, projection)

# %%
# Process incidence angle files
process_inc_files(input_directory, output_directory)

# %% [markdown]
# # 5. Incidence Angle Corrections/Masking
#
# Converting sigma0 to gamma0 should remove most of the range/incidence angle dependency.
#
# gamma0 = sigma0 / cos(incidence angle)

# %%
mask_and_save(input_directory, output_directory)

# %%
## Pre-Fire
# Open the two input rasters using rasterio
with rio.open('SanAnd_08525_14158_003_141023_L090HVHV_02_masked.tif') as src1:
    arr1 = src1.read(1, masked=True)
    meta1 = src1.meta

with rio.open('SanAnd_26526_14092_007_140624_L090HVHV_02_masked.tif') as src2:
    arr2 = src2.read(1, masked=True)
    meta2 = src2.meta

# %%
cmap = 'Greys_r'
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(25,10))

vmin_HV=0
vmax_HV=0.1

# 2014 SanAnd_08525
plot = ax1.imshow(arr1.squeeze(),vmin=vmin_HV, vmax=vmax_HV, cmap=cmap)
ax1.set_title('Incidence Angle Masked - Heading 1')
fig.colorbar(plot, ax=ax1, shrink=0.5)

# 2014 SanAnd_26526
plot = ax2.imshow(arr2.squeeze(), vmin=vmin_HV, vmax=vmax_HV,cmap=cmap)
ax2.set_title('Incidence Angle Masked - Heading 2')
fig.colorbar(plot, ax=ax2, shrink=0.5)

# %%
# Merge the two arrays using numpy's maximum function to take the maximum value at each pixel
merged_arr_prefire = np.nanmax((arr1, arr2), axis=0)

## Post-Fire
# Open the two input rasters using rasterio
with rio.open('SanAnd_26526_17122_004_171102_L090HVHV_02_masked.tif') as src1:
    arr1 = src1.read(1, masked=True)
    meta1 = src1.meta

with rio.open('SanAnd_08525_17122_003_171102_L090HVHV_02_masked.tif') as src2:
    arr2 = src2.read(1, masked=True)
    meta2 = src2.meta

# Merge the two arrays using numpy's maximum function to take the maximum value at each pixel
merged_arr_postfire = np.nanmax((arr1, arr2), axis=0)

# %%
fig, axs = plt.subplots(figsize=(5,5))
plt.imshow(merged_arr_prefire, vmin=0, vmax=0.1, cmap="Greys_r")
plt.title('Pre-Fire merged opposing headings')

# %%
fig, axs = plt.subplots(figsize=(5,5))
plt.imshow(merged_arr_postfire, vmin=0, vmax=0.1, cmap="Greys_r")
plt.title('Post-Fire merged opposing headings')

# %%
plt.figure(figsize=(3, 3))
plt.hist(merged_arr_postfire.flatten(), range = [-0.25, 1.5], bins=200, alpha=0.7, color='blue')
plt.hist(merged_arr_prefire.flatten(), range = [-0.25, 1.5], bins=200, alpha=0.7, color='red')
plt.xlabel('Pixel Values')
plt.ylabel('Frequency')
plt.title('Histogram of NISAR Sim')
plt.show()

# %% [markdown]
# # Lee Filter

# %%
lee_merged_arr_prefire = enhanced_lee(merged_arr_prefire, 5, 1)
lee_merged_arr_postfire = enhanced_lee(merged_arr_postfire, 5, 1)

# %% [markdown]
# # Export
# - HV_log
# - fire severity product
# - send to UAVSAR staging area

# %%
# Open the reference raster
with rio.open(reference_path) as src:
    # Get metadata from the reference raster
    meta = src.meta

    # Update metadata to match the NumPy array
    meta.update({
        'dtype': HV_log.dtype,
        'count': 1  # Assuming there's only one band
    })

    # Save HV Log Ratio
    with rio.open("HV_log_uavsar.tif", 'w', **meta) as dst:
        dst.write(HV_log, 1)  # Assuming there's only one band (band index 1)

    # Save HV Log Ratio Classification
    with rio.open("HV_log_uavsar_classification.tif", 'w', **meta) as dst:
        dst.write(hv_class, 1)  # Assuming there's only one band (band index 1)

    # Filtered Classification
    with rio.open("HV_log_uavsar_classification_filtered.tif", 'w', **meta) as dst:
        dst.write(filtered_image, 1)  # Assuming there's only one band (band index 1)

# %% [markdown]
# or export a data stack
#
# 1. HV Pre-Fire (Merged opposite headings and Lee Filtered)
# 2. HV Post-Fire (Merged opposite headings and Lee Filtered)
# 3. HV Log
# 4. Fire Severity Classification
#
# Could add:
# - incidence angles
# - slope
# - aspect

# %%
# Open the reference raster
with rio.open(reference_raster) as src:
    # Get metadata from the reference raster
    meta = src.meta

    # Update metadata to handle multiple bands
    meta.update({
        'dtype': 'float32',  # Assuming all bands are of float32 dtype
        'count': 4,          # Number of bands
        'driver': 'GTiff'
    })

    # Add band descriptions to the metadata
    meta['descriptions'] = ('HV Pre-Fire', 'HV Post-Fire','HV Log Ratio', 'HV Log Ratio Classification')

    # Create a new stack with multiple bands
    with rio.open("uavsar_stack.tif", 'w', **meta) as dst:
        dst.write(merged_arr_prefire, 1)
        dst.write(merged_arr_postfire, 2)
        dst.write(HV_log, 3)
        dst.write(hv_class, 4)
