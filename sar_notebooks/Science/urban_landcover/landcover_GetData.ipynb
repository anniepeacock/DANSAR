# %% [markdown]
# # UAVSAR Landcover
# ## 1. Get UAVSAR Data
# ## 2. Convert to Geotiff & Subset with GDAL

# %% [markdown]
# Munich: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=munich_19417_15088_002_150605_L090_CX_01#data
#
# Quebec: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=Laurnt_18801_09054_007_090805_L090_CX_01#data
#
# San Diego: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=SanAnd_08503_14081_007_140611_L090_CX_01#data
#
#
# New Orleans: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=gulfco_09010_16020_027_160313_L090_CX_01#data
