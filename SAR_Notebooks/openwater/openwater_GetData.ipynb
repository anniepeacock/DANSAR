# %% [markdown]
# # UAVSAR Open Water
# ## 1. Get UAVSAR Data
# ## 2. Convert to Geotiff & Subset with GDAL

# %% [markdown]
# Panama Subset: (what part of the image is best?)
# -79.8928, 9.0897, -79.8064, 9.0246
#
#
# Panama: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=PCanal_31504_10017_010_100206_L090_CX_02#data
