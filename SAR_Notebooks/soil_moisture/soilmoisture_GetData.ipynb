# %% [markdown]
# # UAVSAR Soil Moisture
# ## 1. Get UAVSAR Data
# ## 2. Convert to Geotiff & Subset with GDAL

# %% [markdown]
# SMAP Feb: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=SMAP13_33006_14017_006_140211_L090_CX_01#data
#
# SMAP April: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=SMAP13_33006_14031_006_140401_L090_CX_01#data
#
# SMAP May: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=SMAP13_33006_14063_009_140519_L090_CX_01#data
#
# SMAP August: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=SMAP13_33006_14112_001_140814_L090_CX_01#data

# %% [markdown]
# for i in *.grd; do gdal_translate -projwin -120.968 38.433 -120.964 38.430 $i $i.tif; done
#
# Tonzi Ranch: 38.4309, -120.9660
