# %% [markdown]
# # UAVSAR Fire
# ## 1. Get UAVSAR Data
# ## 2. Convert to Geotiff & Subset with GDAL

# %% [markdown]
# 2014 Image: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=SanAnd_08525_14158_003_141023_L090_CX_01#data
#
# 2017 Image: https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=SanAnd_08525_17122_003_171102_L090_CX_01#data
#
# Thomas Coherence:  https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=SanAnd_26530_17122-002_18001-007_0095d_s01_L090_02

# %%
# !apt-get update
# !apt-get install libgdal-dev -y
# !apt-get install python-gdal -y

# %%
import gdal

# %% [markdown]
# Verdugo Mountains Extent: [-118.3907205 ,34.16709426, -118.19881626,34.27160262]
#
#
# La Tuna Fire: -118.3907, 34.2716, -118.1988, 34.1671
#
# Thomas Fire Coherence: (not sure which part of image is best)
# -119.6930, 34.5291, -119.4642, 34.3941

# %% [markdown]
# #hdr_commands.sh
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/BuildUAVSARhdr.py -i SanAnd_08525_14158_003_141023_L090_CX_01.ann.txt -r SanAnd_08525_14158_003_141023_L090HHHH_CX_01.grd -p HHHH
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/BuildUAVSARhdr.py -i SanAnd_08525_14158_003_141023_L090_CX_01.ann.txt -r SanAnd_08525_14158_003_141023_L090HVHV_CX_01.grd -p HVHV
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/BuildUAVSARhdr.py -i SanAnd_08525_14158_003_141023_L090_CX_01.ann.txt -r SanAnd_08525_14158_003_141023_L090VVVV_CX_01.grd -p VVVV
#
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/BuildUAVSARhdr.py -i SanAnd_08525_17122_003_171102_L090_CX_01.ann.txt -r SanAnd_08525_17122_003_171102_L090HHHH_CX_01.grd -p HHHH
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/BuildUAVSARhdr.py -i SanAnd_08525_17122_003_171102_L090_CX_01.ann.txt -r SanAnd_08525_17122_003_171102_L090HVHV_CX_01.grd -p HVHV
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/BuildUAVSARhdr.py -i SanAnd_08525_17122_003_171102_L090_CX_01.ann.txt -r SanAnd_08525_17122_003_171102_L090VVVV_CX_01.grd -p VVVV
#
#
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/BuildUAVSARhdr.py -i SanAnd_26530_17122-002_18001-007_0095d_s01_L090HH_02.ann.txt -r SanAnd_26530_17122-002_18001-007_0095d_s01_L090HH_02.cor.grd -p HHHH
#
# ----------------------------------------------
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/raster_read.py -i SanAnd_26530_17122-002_18001-007_0095d_s01_L090HH_02.cor.grd
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/raster_read.py -i SanAnd_08525_14158_003_141023_L090HHHH_CX_01.grd -a -118.3907 -b 34.2716 -c -118.1988 -d 34.1671
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/raster_read.py -i SanAnd_08525_14158_003_141023_L090HVHV_CX_01.grd -a -118.3907 -b 34.2716 -c -118.1988 -d 34.1671
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/raster_read.py -i SanAnd_08525_14158_003_141023_L090VVVV_CX_01.grd -a -118.3907 -b 34.2716 -c -118.1988 -d 34.1671
#
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/raster_read.py -i SanAnd_08525_17122_003_171102_L090HHHH_CX_01.grd -a -118.3907 -b 34.2716 -c -118.1988 -d 34.1671
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/raster_read.py -i SanAnd_08525_17122_003_171102_L090HVHV_CX_01.grd -a -118.3907 -b 34.2716 -c -118.1988 -d 34.1671
#
# python /Users/peacock/Desktop/UAVSAR_Quicklooks/raster_read.py -i SanAnd_08525_17122_003_171102_L090VVVV_CX_01.grd -a -118.3907 -b 34.2716 -c -118.1988 -d 34.1671
#
# -----------------------------------------------
# gdal_translate SanAnd_08525_17122_003_171102_L090HHHH_CX_01.grd.tif SanAnd_08525_17122_003_171102_L090HHHH_CX_01_cropped.grd.tif -projwin -118.3907 34.2716 -118.1988 34.1671
# gdal_translate SanAnd_08525_17122_003_171102_L090HVHV_CX_01.grd.tif SanAnd_08525_17122_003_171102_L090HVHV_CX_01_cropped.grd.tif -projwin -118.3907 34.2716 -118.1988 34.1671
# gdal_translate SanAnd_08525_17122_003_171102_L090VVVV_CX_01.grd.tif SanAnd_08525_17122_003_171102_L090VVVV_CX_01_cropped.grd.tif -projwin -118.3907 34.2716 -118.1988 34.1671
#
# gdal_translate SanAnd_08525_14158_003_141023_L090HHHH_CX_01.grd.tif SanAnd_08525_14158_003_141023_L090HHHH_CX_01_cropped.grd.tif -projwin -118.3907 34.2716 -118.1988 34.1671
# gdal_translate SanAnd_08525_14158_003_141023_L090HVHV_CX_01.grd.tif SanAnd_08525_14158_003_141023_L090HVHV_CX_01_cropped.grd.tif -projwin -118.3907 34.2716 -118.1988 34.1671
# gdal_translate SanAnd_08525_14158_003_141023_L090VVVV_CX_01.grd.tif SanAnd_08525_14158_003_141023_L090VVVV_CX_01_cropped.grd.tif -projwin -118.3907 34.2716 -118.1988 34.1671
#
#
#
# ## Crop Thomas Fire, Santa Barbara Coherence
#
# gdal_translate SanAnd_26530_17122-002_18001-007_0095d_s01_L090HH_02.cor.grd.tif SanAnd_26530_17122-002_18001-007_0095d_s01_L090HH_02_cropped.cor.grd.tif -projwin -119.693 34.5291 -119.4642 34.3941
