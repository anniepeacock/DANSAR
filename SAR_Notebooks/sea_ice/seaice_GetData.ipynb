# %% [markdown]
# # UAVSAR Sea Ice
# ## 1. Get UAVSAR Data
# ## 2. Convert to Geotiff & Subset with GDAL

# %% [markdown]
# https://uavsar.jpl.nasa.gov/cgi-bin/product.pl?jobName=beaufo_01104_15148_000_151006_L090_CX_03#data (VV and HH)
